# %% [markdown]
# # Hydroserving application tests

# %%
# !pip install docker
# !pip install opencv-python
# !apt update && apt install -y libsm6 libxext6 libfontconfig1 libxrender1
# !pip install hydro_serving_grpc
# !pip install hs==0.0.5
# Out:
# Requirement already satisfied: docker in /Users/bulat/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: docker-pycreds>=0.2.1 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker)
# Requirement already satisfied: six>=1.4.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker)
# Requirement already satisfied: opencv-python in /Users/bulat/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: numpy>=1.11.1 in /Users/bulat/anaconda/lib/python3.6/site-packages (from opencv-python)
# Unable to locate an executable at "/Library/Java/JavaVirtualMachines/jdk1.8.0_131.jdk/Contents/Home/bin/apt" (-1)
# Requirement already satisfied: hydro_serving_grpc in /Users/bulat/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: protobuf>=3.3.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hydro_serving_grpc)
# Requirement already satisfied: grpcio>=1.7.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hydro_serving_grpc)
# Requirement already satisfied: setuptools in /Users/bulat/anaconda/lib/python3.6/site-packages (from protobuf>=3.3.0->hydro_serving_grpc)
# Requirement already satisfied: six>=1.9 in /Users/bulat/anaconda/lib/python3.6/site-packages (from protobuf>=3.3.0->hydro_serving_grpc)
# Requirement already satisfied: hs==0.0.5 in /Users/bulat/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: click==6.7 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hs==0.0.5)
# Requirement already satisfied: hydro-serving-grpc==0.0.14 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hs==0.0.5)
# Requirement already satisfied: kafka-python==1.4.1 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hs==0.0.5)
# Requirement already satisfied: docker==3.0.1 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hs==0.0.5)
# Requirement already satisfied: pyyaml in /Users/bulat/anaconda/lib/python3.6/site-packages (from hs==0.0.5)
# Requirement already satisfied: grpcio>=1.7.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hydro-serving-grpc==0.0.14->hs==0.0.5)
# Requirement already satisfied: protobuf>=3.3.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from hydro-serving-grpc==0.0.14->hs==0.0.5)
# Requirement already satisfied: docker-pycreds>=0.2.1 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker==3.0.1->hs==0.0.5)
# Requirement already satisfied: six>=1.4.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker==3.0.1->hs==0.0.5)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker==3.0.1->hs==0.0.5)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /Users/bulat/anaconda/lib/python3.6/site-packages (from docker==3.0.1->hs==0.0.5)
# Requirement already satisfied: setuptools in /Users/bulat/anaconda/lib/python3.6/site-packages (from protobuf>=3.3.0->hydro-serving-grpc==0.0.14->hs==0.0.5)

# %% [markdown]
# !cd /Users/bulat/Documents/Dev/Provectus/hydro-serving && MODEL_DIRECTORY=/Users/bulat/Documents/Dev/Provectus/hydro-serving-runtime/models docker-compose up -d

# %%
from hydroserving.httpclient import HydroservingClient
hs_api = HydroservingClient("http://serving-demo.hydrosphere.io")

hs_api.models.list()
# Out:
# [{'lastModelBuild': {'finished': '2018-03-06T05:14:21.106',
#    'id': 1,
#    'model': {'created': '2018-03-06T05:10:52.686',
#     'id': 4,
#     'modelContract': 'model_name: "word2vec"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'spark:2.1',
#     'name': 'word2vec',
#     'source': 'local:word2vec',
#     'updated': '2018-03-06T15:06:22.476'},
#    'modelVersion': {'created': '2018-03-06T05:14:21.1',
#     'id': 1,
#     'imageName': 'word2vec',
#     'imageSHA256': 'd206cd9393edee8573e3f3221e6111f70610b9103ec36a523eb7d930342b203e',
#     'imageTag': '1',
#     'model': {'created': '2018-03-06T05:10:52.686',
#      'id': 4,
#      'modelContract': 'model_name: "word2vec"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#      'modelType': 'spark:2.1',
#      'name': 'word2vec',
#      'source': 'local:word2vec',
#      'updated': '2018-03-06T15:06:22.476'},
#     'modelContract': 'model_name: "word2vec"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelName': 'word2vec',
#     'modelType': 'spark:2.1',
#     'modelVersion': 1,
#     'source': 'local:word2vec'},
#    'started': '2018-03-06T05:14:18.142',
#    'status': 'FINISHED',
#    'statusText': 'OK',
#    'version': 1},
#   'lastModelVersion': {'created': '2018-03-06T05:14:21.1',
#    'id': 1,
#    'imageName': 'word2vec',
#    'imageSHA256': 'd206cd9393edee8573e3f3221e6111f70610b9103ec36a523eb7d930342b203e',
#    'imageTag': '1',
#    'model': {'created': '2018-03-06T05:10:52.686',
#     'id': 4,
#     'modelContract': 'model_name: "word2vec"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'spark:2.1',
#     'name': 'word2vec',
#     'source': 'local:word2vec',
#     'updated': '2018-03-06T15:06:22.476'},
#    'modelContract': 'model_name: "word2vec"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelName': 'word2vec',
#    'modelType': 'spark:2.1',
#    'modelVersion': 1,
#    'source': 'local:word2vec'},
#   'model': {'created': '2018-03-06T05:10:52.686',
#    'id': 4,
#    'modelContract': 'model_name: "word2vec"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.1',
#    'name': 'word2vec',
#    'source': 'local:word2vec',
#    'updated': '2018-03-06T15:06:22.476'},
#   'nextVersion': 2},
#  {'lastModelBuild': {'finished': '2018-03-06T10:12:16.501',
#    'id': 4,
#    'model': {'created': '2018-03-06T05:10:52.557',
#     'id': 1,
#     'modelContract': 'model_name: ""\n',
#     'modelType': 'scikit',
#     'name': 'iris_svm',
#     'source': 'local:iris_svm',
#     'updated': '2018-03-06T15:06:23.508'},
#    'modelVersion': {'created': '2018-03-06T10:12:16.498',
#     'id': 4,
#     'imageName': 'iris_svm',
#     'imageSHA256': '2b458443a71eb95e0daeb97a6d5e2d9d676995f1ba0b021d1e55f63e0e3b048d',
#     'imageTag': '1',
#     'model': {'created': '2018-03-06T05:10:52.557',
#      'id': 1,
#      'modelContract': 'model_name: ""\n',
#      'modelType': 'scikit',
#      'name': 'iris_svm',
#      'source': 'local:iris_svm',
#      'updated': '2018-03-06T15:06:23.508'},
#     'modelContract': 'model_name: ""\n',
#     'modelName': 'iris_svm',
#     'modelType': 'scikit',
#     'modelVersion': 1,
#     'source': 'local:iris_svm'},
#    'started': '2018-03-06T10:12:15.655',
#    'status': 'FINISHED',
#    'statusText': 'OK',
#    'version': 1},
#   'lastModelVersion': {'created': '2018-03-06T10:12:16.498',
#    'id': 4,
#    'imageName': 'iris_svm',
#    'imageSHA256': '2b458443a71eb95e0daeb97a6d5e2d9d676995f1ba0b021d1e55f63e0e3b048d',
#    'imageTag': '1',
#    'model': {'created': '2018-03-06T05:10:52.557',
#     'id': 1,
#     'modelContract': 'model_name: ""\n',
#     'modelType': 'scikit',
#     'name': 'iris_svm',
#     'source': 'local:iris_svm',
#     'updated': '2018-03-06T15:06:23.508'},
#    'modelContract': 'model_name: ""\n',
#    'modelName': 'iris_svm',
#    'modelType': 'scikit',
#    'modelVersion': 1,
#    'source': 'local:iris_svm'},
#   'model': {'created': '2018-03-06T05:10:52.557',
#    'id': 1,
#    'modelContract': 'model_name: ""\n',
#    'modelType': 'scikit',
#    'name': 'iris_svm',
#    'source': 'local:iris_svm',
#    'updated': '2018-03-06T15:06:23.508'},
#   'nextVersion': 2},
#  {'lastModelBuild': {'finished': '2018-03-06T15:19:16.959',
#    'id': 6,
#    'model': {'created': '2018-03-06T05:10:52.703',
#     'id': 5,
#     'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'spark:2.1',
#     'name': 'minmaxscaler',
#     'source': 'local:minmaxscaler',
#     'updated': '2018-03-06T15:06:23.529'},
#    'modelVersion': {'created': '2018-03-06T15:19:16.955',
#     'id': 6,
#     'imageName': 'minmaxscaler',
#     'imageSHA256': 'af82d11438d1124a41a52eb59ebefeb93c853d61bb72f80e7df8c6e8311067f8',
#     'imageTag': '1',
#     'model': {'created': '2018-03-06T05:10:52.703',
#      'id': 5,
#      'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#      'modelType': 'spark:2.1',
#      'name': 'minmaxscaler',
#      'source': 'local:minmaxscaler',
#      'updated': '2018-03-06T15:06:23.529'},
#     'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelName': 'minmaxscaler',
#     'modelType': 'spark:2.1',
#     'modelVersion': 1,
#     'source': 'local:minmaxscaler'},
#    'started': '2018-03-06T15:19:15.914',
#    'status': 'FINISHED',
#    'statusText': 'OK',
#    'version': 1},
#   'lastModelVersion': {'created': '2018-03-06T15:19:16.955',
#    'id': 6,
#    'imageName': 'minmaxscaler',
#    'imageSHA256': 'af82d11438d1124a41a52eb59ebefeb93c853d61bb72f80e7df8c6e8311067f8',
#    'imageTag': '1',
#    'model': {'created': '2018-03-06T05:10:52.703',
#     'id': 5,
#     'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'spark:2.1',
#     'name': 'minmaxscaler',
#     'source': 'local:minmaxscaler',
#     'updated': '2018-03-06T15:06:23.529'},
#    'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelName': 'minmaxscaler',
#    'modelType': 'spark:2.1',
#    'modelVersion': 1,
#    'source': 'local:minmaxscaler'},
#   'model': {'created': '2018-03-06T05:10:52.703',
#    'id': 5,
#    'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.1',
#    'name': 'minmaxscaler',
#    'source': 'local:minmaxscaler',
#    'updated': '2018-03-06T15:06:23.529'}},
#  {'model': {'created': '2018-03-06T05:11:38.493',
#    'id': 28,
#    'modelContract': 'model_name: "iris_decision_tree_classifier"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "indexedLabel"\n    info {\n      dtype: DT_DOUBLE\n    }\n  }\n  outputs {\n    field_name: "prediction"\n    info {\n      dtype: DT_DOUBLE\n    }\n  }\n  outputs {\n    field_name: "rawPrediction"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "probability"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.2',
#    'name': 'iris_decision_tree_classifier',
#    'source': 's3:iris_decision_tree_classifier',
#    'updated': '2018-03-06T15:07:22.364'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:40.915',
#    'id': 30,
#    'modelContract': 'model_name: "word_2_vec_2"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.1',
#    'name': 'word_2_vec_2',
#    'source': 's3:word_2_vec_2',
#    'updated': '2018-03-06T15:07:24.944'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:42.112',
#    'id': 31,
#    'modelContract': 'model_name: "word2vecnew"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.2',
#    'name': 'word2vecnew',
#    'source': 's3:word2vecnew',
#    'updated': '2018-03-06T15:07:26.249'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:44.844',
#    'id': 33,
#    'modelContract': 'model_name: "tf_mnist_classifier"\nsignatures {\n  signature_name: "tensorflow/serving/predict"\n  inputs {\n    field_name: "images"\n    info {\n      dtype: DT_FLOAT\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 784\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "images"\n    info {\n      dtype: DT_FLOAT\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 784\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'tensorflow',
#    'name': 'tf_mnist_classifier',
#    'source': 's3:tf_mnist_classifier',
#    'updated': '2018-03-06T15:07:28.116'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:46.172',
#    'id': 34,
#    'modelContract': 'model_name: "word_2_vec_new"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.1',
#    'name': 'word_2_vec_new',
#    'source': 's3:word_2_vec_new',
#    'updated': '2018-03-06T15:07:29.542'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:48.654',
#    'id': 36,
#    'modelContract': 'model_name: "word_2_vec"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.2',
#    'name': 'word_2_vec',
#    'source': 's3:word_2_vec',
#    'updated': '2018-03-06T15:07:32.265'},
#   'nextVersion': 1},
#  {'lastModelBuild': {'finished': '2018-03-06T10:12:58.482',
#    'id': 5,
#    'model': {'created': '2018-03-06T05:10:52.673',
#     'id': 2,
#     'modelContract': 'model_name: "standardscaler"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'spark:2.1',
#     'name': 'standardscaler',
#     'source': 'local:standardscaler',
#     'updated': '2018-03-06T15:06:22.459'},
#    'modelVersion': {'created': '2018-03-06T10:12:58.479',
#     'id': 5,
#     'imageName': 'standardscaler',
#     'imageSHA256': '0e1dd10bfdb34ce14c5be4ffbe93d3926caacaff5647d6fc6bf22727694022de',
#     'imageTag': '2',
#     'model': {'created': '2018-03-06T05:10:52.673',
#      'id': 2,
#      'modelContract': 'model_name: "standardscaler"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#      'modelType': 'spark:2.1',
#      'name': 'standardscaler',
#      'source': 'local:standardscaler',
#      'updated': '2018-03-06T15:06:22.459'},
#     'modelContract': 'model_name: "standardscaler"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelName': 'standardscaler',
#     'modelType': 'spark:2.1',
#     'modelVersion': 2,
#     'source': 'local:standardscaler'},
#    'started': '2018-03-06T10:12:57.639',
#    'status': 'FINISHED',
#    'statusText': 'OK',
#    'version': 2},
#   'lastModelVersion': {'created': '2018-03-06T10:12:58.479',
#    'id': 5,
#    'imageName': 'standardscaler',
#    'imageSHA256': '0e1dd10bfdb34ce14c5be4ffbe93d3926caacaff5647d6fc6bf22727694022de',
#    'imageTag': '2',
#    'model': {'created': '2018-03-06T05:10:52.673',
#     'id': 2,
#     'modelContract': 'model_name: "standardscaler"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'spark:2.1',
#     'name': 'standardscaler',
#     'source': 'local:standardscaler',
#     'updated': '2018-03-06T15:06:22.459'},
#    'modelContract': 'model_name: "standardscaler"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelName': 'standardscaler',
#    'modelType': 'spark:2.1',
#    'modelVersion': 2,
#    'source': 'local:standardscaler'},
#   'model': {'created': '2018-03-06T05:10:52.673',
#    'id': 2,
#    'modelContract': 'model_name: "standardscaler"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scaledFeatures"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.1',
#    'name': 'standardscaler',
#    'source': 'local:standardscaler',
#    'updated': '2018-03-06T15:06:22.459'},
#   'nextVersion': 3},
#  {'model': {'created': '2018-03-06T05:11:37.237',
#    'id': 27,
#    'modelContract': 'model_name: "mnist_decision_tree_classifier"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "features"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 780\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "indexedLabel"\n    info {\n      dtype: DT_DOUBLE\n    }\n  }\n  outputs {\n    field_name: "prediction"\n    info {\n      dtype: DT_DOUBLE\n    }\n  }\n  outputs {\n    field_name: "rawPrediction"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 780\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "probability"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 780\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.2',
#    'name': 'mnist_decision_tree_classifier',
#    'source': 's3:mnist_decision_tree_classifier',
#    'updated': '2018-03-06T15:07:21.134'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:39.714',
#    'id': 29,
#    'modelContract': 'model_name: ""\n',
#    'modelType': 'scikit',
#    'name': 'linear_diamonds_databricks',
#    'source': 's3:linear_diamonds_databricks',
#    'updated': '2018-03-06T15:07:23.609'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:43.956',
#    'id': 32,
#    'modelContract': 'model_name: "tensorflow_mnist_classifier"\nsignatures {\n  signature_name: "tensorflow/serving/predict"\n  inputs {\n    field_name: "images"\n    info {\n      dtype: DT_FLOAT\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 784\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "images"\n    info {\n      dtype: DT_FLOAT\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 784\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'tensorflow',
#    'name': 'tensorflow_mnist_classifier',
#    'source': 's3:tensorflow_mnist_classifier',
#    'updated': '2018-03-06T15:07:27.183'},
#   'nextVersion': 1},
#  {'model': {'created': '2018-03-06T05:11:47.381',
#    'id': 35,
#    'modelContract': 'model_name: "word_2_vec_22"\nsignatures {\n  signature_name: "default_spark"\n  inputs {\n    field_name: "text"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "result"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: 3\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'spark:2.2',
#    'name': 'word_2_vec_22',
#    'source': 's3:word_2_vec_22',
#    'updated': '2018-03-06T15:07:30.981'},
#   'nextVersion': 1},
#  {'lastModelBuild': {'finished': '2018-03-06T07:17:46.477',
#    'id': 3,
#    'model': {'created': '2018-03-06T07:10:37.53',
#     'id': 37,
#     'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "detect"\n  inputs {\n    field_name: "image_b64"\n    info {\n      dtype: DT_STRING\n    }\n  }\n  outputs {\n    field_name: "bboxes"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scores"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "classes"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'unknown:ssd_demo',
#     'name': 'ssd_model_example',
#     'source': 's3:ssd_model_example',
#     'updated': '2018-03-06T15:07:33.599'},
#    'modelVersion': {'created': '2018-03-06T07:17:46.473',
#     'id': 3,
#     'imageName': 'ssd_model_example',
#     'imageSHA256': '82efc2a5783b3da9cdff542c69c30094f94dd4faa3f37c220e0b87963ac34b57',
#     'imageTag': '1',
#     'model': {'created': '2018-03-06T07:10:37.53',
#      'id': 37,
#      'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "detect"\n  inputs {\n    field_name: "image_b64"\n    info {\n      dtype: DT_STRING\n    }\n  }\n  outputs {\n    field_name: "bboxes"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scores"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "classes"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#      'modelType': 'unknown:ssd_demo',
#      'name': 'ssd_model_example',
#      'source': 's3:ssd_model_example',
#      'updated': '2018-03-06T15:07:33.599'},
#     'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "detect"\n  inputs {\n    field_name: "image_b64"\n    info {\n      dtype: DT_STRING\n    }\n  }\n  outputs {\n    field_name: "bboxes"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scores"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "classes"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelName': 'ssd_model_example',
#     'modelType': 'unknown:ssd_demo',
#     'modelVersion': 1,
#     'source': 's3:ssd_model_example'},
#    'started': '2018-03-06T07:17:02.991',
#    'status': 'FINISHED',
#    'statusText': 'OK',
#    'version': 1},
#   'lastModelVersion': {'created': '2018-03-06T07:17:46.473',
#    'id': 3,
#    'imageName': 'ssd_model_example',
#    'imageSHA256': '82efc2a5783b3da9cdff542c69c30094f94dd4faa3f37c220e0b87963ac34b57',
#    'imageTag': '1',
#    'model': {'created': '2018-03-06T07:10:37.53',
#     'id': 37,
#     'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "detect"\n  inputs {\n    field_name: "image_b64"\n    info {\n      dtype: DT_STRING\n    }\n  }\n  outputs {\n    field_name: "bboxes"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scores"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "classes"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#     'modelType': 'unknown:ssd_demo',
#     'name': 'ssd_model_example',
#     'source': 's3:ssd_model_example',
#     'updated': '2018-03-06T15:07:33.599'},
#    'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "detect"\n  inputs {\n    field_name: "image_b64"\n    info {\n      dtype: DT_STRING\n    }\n  }\n  outputs {\n    field_name: "bboxes"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scores"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "classes"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelName': 'ssd_model_example',
#    'modelType': 'unknown:ssd_demo',
#    'modelVersion': 1,
#    'source': 's3:ssd_model_example'},
#   'model': {'created': '2018-03-06T07:10:37.53',
#    'id': 37,
#    'modelContract': 'model_name: ""\nsignatures {\n  signature_name: "detect"\n  inputs {\n    field_name: "image_b64"\n    info {\n      dtype: DT_STRING\n    }\n  }\n  outputs {\n    field_name: "bboxes"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scores"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "classes"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n',
#    'modelType': 'unknown:ssd_demo',
#    'name': 'ssd_model_example',
#    'source': 's3:ssd_model_example',
#    'updated': '2018-03-06T15:07:33.599'},
#   'nextVersion': 2}]

# %%
py36 = hs_api.add_runtime('hydrosphere/serving-runtime-python', '3.6-latest', ['unknown:ssd_demo', "python:3.6"])
print("Done")
# Out:
# Adding hydrosphere/serving-runtime-python:3.6-latest runtime ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-16-edf50595000e> in <module>()
#      11 # tf14 = hs_api.add_runtime('hydrosphere/serving-runtime-tensorflow', '1.4.0-latest', 'tensorflow')
#      12
# ---> 13 py36 = hs_api.add_runtime('hydrosphere/serving-runtime-python', '3.6-latest', ['unknown:ssd_demo', "python:3.6"])
#      14 print("Done")
#
# <ipython-input-11-69b92d21b306> in add_runtime(self, name, version, rtype, pull)
#      47               "configParams": {}
#      48         }
# ---> 49         return self.post(url, data)
#      50
#      51     def build_model(self, model_id):
#
# <ipython-input-11-69b92d21b306> in post(self, url, data)
#      18         json_data = json.dumps(data)
#      19         req = urllib.request.Request(url, json_data.encode('utf-8'), {'Content-Type': 'application/json'})
# ---> 20         f = urllib.request.urlopen(req)
#      21         response = json.loads(f.read().decode("utf-8"))
#      22         f.close()
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 405: Method Not Allowed

# %%
# build model version
ssd_model = list(filter(lambda m: m['model']['name'] == 'fat_ssd_example', hs_api.get_models()))[0]

ssd_model_version = hs_api.build_model(ssd_model['model']['id'])
print(ssd_model_version)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-13-6ceb15b37767> in <module>()
#       2 ssd_model = list(filter(lambda m: m['model']['name'] == 'fat_ssd_example', hs_api.get_models()))[0]
#       3
# ----> 4 ssd_model_version = hs_api.build_model(ssd_model['model']['id'])
#       5 print(ssd_model_version)
#
# <ipython-input-11-69b92d21b306> in build_model(self, model_id)
#      54           "modelId": model_id
#      55         }
# ---> 56         return self.post(url, data)
#      57
#      58     def add_application(self, application):
#
# <ipython-input-11-69b92d21b306> in post(self, url, data)
#      18         json_data = json.dumps(data)
#      19         req = urllib.request.Request(url, json_data.encode('utf-8'), {'Content-Type': 'application/json'})
# ---> 20         f = urllib.request.urlopen(req)
#      21         response = json.loads(f.read().decode("utf-8"))
#      22         f.close()
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda/envs/tensorflow/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 504: Gateway Timeout

# %%
# create application
application = {
  "name": "true_ssd_app",
  "executionGraph": {
    "stages": [
      {
        "services": [
          {
            "runtimeId": 3, #py36["id"],
            "modelVersionId": 2,
            "weight": 100,
            "signatureName": "detect"
          }
        ]
      }
    ]
  },
  "kafkaStreaming": []
}

created_app = hs_api.add_application(application)
print(created_app)
# Out:
# {'name': 'true_ssd_app', 'kafkaStreaming': [], 'id': 4, 'executionGraph': {'stages': [{'services': [{'serviceDescription': {'runtimeId': 3, 'modelVersionId': 2}, 'weight': 100}]}]}, 'contract': 'model_name: ""\nsignatures {\n  signature_name: "detect"\n  inputs {\n    field_name: "image_b64"\n    info {\n      dtype: DT_STRING\n    }\n  }\n  outputs {\n    field_name: "bboxes"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        dim {\n          size: 4\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "scores"\n    info {\n      dtype: DT_DOUBLE\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n  outputs {\n    field_name: "classes"\n    info {\n      dtype: DT_STRING\n      tensor_shape {\n        dim {\n          size: -1\n          name: ""\n        }\n        unknown_rank: false\n      }\n    }\n  }\n}\n'}

# %%
# %matplotlib inline
from show_result import show_result

def serve_folder(pictures_folder):
    channel = grpc.insecure_channel('sidecar:8080')
    client = hs.PredictionServiceStub(channel=channel)

    pics_dir = pictures_folder
    for file in os.listdir(pics_dir):
        full_file_path = os.path.join(pics_dir, file)

        if (not os.path.isfile(full_file_path)):
            print("Skipped: {}".format(full_file_path))
            continue

        print("Serving: {}".format(full_file_path))

        with open(full_file_path, "rb") as image_file:
            encoded_string = base64.b64encode(image_file.read())

        image_tensor = hs.TensorProto(
            dtype=hs.DT_STRING,
            string_val=[encoded_string]
        )

        request = hs.PredictRequest(
            model_spec=hs.ModelSpec(signature_name="detect", name=created_app["name"]),
            inputs={
                "image_b64": image_tensor,
            }
        )

        result = client.Predict(request)

        show_result(full_file_path, result)

# %%
serve_folder("./pics")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6d8a713a9122> in <module>()
# ----> 1 serve_folder("./pics")
#
# <ipython-input-4-9b9ed7f1cdb0> in serve_folder(pictures_folder)
#       3
#       4 def serve_folder(pictures_folder):
# ----> 5     channel = grpc.insecure_channel('sidecar:8080')
#       6     client = hs.PredictionServiceStub(channel=channel)
#       7
#
# NameError: name 'grpc' is not defined

# %%
serve_folder("./cars")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-007eb228eeb6> in <module>()
# ----> 1 serve_folder("./cars")
#
# <ipython-input-4-9b9ed7f1cdb0> in serve_folder(pictures_folder)
#       3
#       4 def serve_folder(pictures_folder):
# ----> 5     channel = grpc.insecure_channel('sidecar:8080')
#       6     client = hs.PredictionServiceStub(channel=channel)
#       7
#
# NameError: name 'grpc' is not defined

# %%
serve_folder("./buldozers")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-68e48e9e7936> in <module>()
# ----> 1 serve_folder("./buldozers")
#
# <ipython-input-4-9b9ed7f1cdb0> in serve_folder(pictures_folder)
#       3
#       4 def serve_folder(pictures_folder):
# ----> 5     channel = grpc.insecure_channel('sidecar:8080')
#       6     client = hs.PredictionServiceStub(channel=channel)
#       7
#
# NameError: name 'grpc' is not defined
